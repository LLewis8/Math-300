# %% [markdown]
# # Week 2 Day 3 Lab

# %% [markdown]
# ## Problem 1
# Import `numpy`, `math`, and `sympy`.

# %%
import numpy
import math
import sympy

# %% [markdown]
# ## Problem 2
#
# 1. Write a recursive function `factorial()` that takes in a natural number `n` and computes $n!=n(n-1)(n-2)\cdots3\cdot2\cdot 1$.
# 2. Use `%timeit` to determine how fast your function calculates `factorial(150)`.
# 3. Use `%timeit` to calculate how fast `math.factorial()` calculates the same quantity.
# 4. Were there any differences between the two methods?

# %%
import math
def factorial(n):
    if n == 0 or n == 1:
        return 1
    
    return n * factorial(n-1)
print(factorial(150))
# %timeit math.factorial(150)


#Yes there are differences between the two methods
# Out:
# 
# 1.57 μs ± 49.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Problem 3
# Recall for a quadratic equation of the form
# $$ax^2 + bx + c = 0
# $$
#
# The solutions are given by the <i>quadratic formula</i>:
#
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# 1. Write a function `quadratic()` that calculates the two roots given by the quadratic formula only if they are real.
# 2. Use `%timeit` to determine how fast your function calculates the roots for $437x^2 - 915x + 478 = 0$.
# 3. Use `%timeit` to calculate how fast `sp.solve()` calculates the same quantities.
# 4. Were there any differences between the two methods?

# %%
import math 
import sympy as sp
def quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None
    root1 = (-b + math.sqrt(discriminant)) / (2*a)
    root2 = (-b - math.sqrt(discriminant)) / (2*a)
    return root1, root2
print(quadratic(437, -915, 478))
# %timeit quadratic(437, -915, 478)
x = sp.symbols('x')
equation = 437*x**2 - 915*x + 478
# %timeit sp.solve(equation, x)
#Yes there were differences between the two methods, the sympy method is faster and more efficient than the math method.
# Out:
# (1.0938215102974829, 1.0)
# 454 ns ± 22.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 2.55 ms ± 270 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Problem 4
#
# For each of the following functions, use `sympy` calculate the first derivative, the second derivative, and the integral (all with respect to $x$):
#
# 1. $f(x)=x$
# 2. $f(x)=6x^{-1/2}$
# 3. $f(x)=\pi\sqrt{x}+x^5+7$
# 4. $f(x)=x(2x-5)(3+\tan(x))$

# %%
import sympy as sp
x = sp.symbols('x')
functions = [
    x,
    6*x**(-1/2),
    sp.pi*sp.sqrt(x) + x**5 + 7,
    x*(2*x - 5)*(3 + sp.tan(x))
]
for f in functions:
    print("Functions:", f)

    first = sp.diff(f, x)
    print("First Derivative:")
    print(first)

    second = sp.diff(f, x, 2)
    print("Second Derivative:")
    print(second)

    integral = sp.integrate(f, x)
    print("Integral:")
    print(integral)

    print("--------------------------------------------------")
# Out:
# Functions: x
# First Derivative:
# 1
# Second Derivative:
# 0
# Integral:
# x**2/2
# --------------------------------------------------
# Functions: 6/x**0.5
# First Derivative:
# -3.0/x**1.5
# Second Derivative:
# 4.5/x**2.5
# Integral:
# 12.0*x**0.5
# --------------------------------------------------
# Functions: pi*sqrt(x) + x**5 + 7
# First Derivative:
# 5*x**4 + pi/(2*sqrt(x))
# Second Derivative:
# 20*x**3 - pi/(4*x**(3/2))
# Integral:
# 2*pi*x**(3/2)/3 + x**6/6 + 7*x
# --------------------------------------------------
# Functions: x*(2*x - 5)*(tan(x) + 3)
# First Derivative:
# x*(2*x - 5)*(tan(x)**2 + 1) + 2*x*(tan(x) + 3) + (2*x - 5)*(tan(x) + 3)
# Second Derivative:
# 2*(x*(2*x - 5)*(tan(x)**2 + 1)*tan(x) + 2*x*(tan(x)**2 + 1) + (2*x - 5)*(tan(x)**2 + 1) + 2*tan(x) + 6)
# Integral:
# Integral(x*(2*x - 5)*(tan(x) + 3), x)
# --------------------------------------------------

# %% [markdown]
# ## Problem 5
#
# From yesterday, we calculated <i>numerically</i> what the derivative of $\sin(x)$ is.
# 1. Using sympy, calculate derivative at 0.
# 2. Using sympy, evaluate the limit definition of the derivative for $f(x)=\sin(x)$:
# $$f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $$

# %%
import sympy as sp

x, h = sp.symbols('x h')
f = sp.sin(x)
derivative = sp.diff(f, x)
print("derivative:")
print(derivative)

value = derivative.subs(x, 0)
print("value at x=0:")
print(value)

limit = sp.limit((sp.sin(x + h) - sp.sin(x)) / h, h, 0)
print("limit:")
print(limit)
# Out:
# derivative:
# cos(x)
# value at x=0:
# 1
# limit:
# cos(x)
